# %% [markdown]
# <a href="https://colab.research.google.com/github/hiagodearaujodantasteixeira/An-lise-de-Dados/blob/main/Introdu%C3%A7%C3%A3o%20ao%20Google%20Colab/Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
caminho = '/content/drive/MyDrive/Classroom/Workshop de Introdução à Ciência de Dados/spotify_processed.csv'

# %%
df_spotify = pd.read_csv(caminho)

# %%
print("Primeiras 7 músicas da tabela: ")
# Out:
# Primeiras 7 músicas da tabela:

# %%
display(df_spotify.head(7))
# Out:
#                    timestamp  duration_ms                         track_name  \
# 0  2017-11-04 21:53:34+00:00        48330                            Silence
# 1  2017-11-04 21:53:46+00:00        11190        Mask Off - Marshmello Remix
# 2  2017-11-04 21:53:53+00:00         5970                             Summer
# 3  2017-11-04 21:54:23+00:00        28640  Chasing Colors (feat. Noah Cyrus)
# 4  2017-11-04 21:54:57+00:00        31050                            Know Me
# 5  2017-11-04 21:55:17+00:00        18780                              Faded
# 6  2017-11-04 21:58:37+00:00       199111   All Falls Down (feat. Juliander)
#
#    artist_name                         album_name
# 0   Marshmello                            Silence
# 1       Future                           Mask Off
# 2   Marshmello                            Joytime
# 3   Marshmello  Chasing Colors (feat. Noah Cyrus)
# 4   Marshmello                            Joytime
# ...

# %%
print("Ultimas 4 músicas da tabela: ")
# Out:
# Ultimas 4 músicas da tabela:

# %%
display(df_spotify.tail(4))
# Out:
#                         timestamp  duration_ms      track_name artist_name  \
# 211889  2025-10-02 23:47:02+00:00        76650     Cementality  King Krule
# 211890  2025-10-02 23:51:22+00:00       259746  A Lizard State  King Krule
# 211891  2025-10-02 23:53:17+00:00       114987     Will I Come  King Krule
# 211892  2025-10-02 23:56:48+00:00       211453       Ocean Bed  King Krule
#
#                      album_name
# 211889  6 Feet Beneath the Moon
# 211890  6 Feet Beneath the Moon
# 211891  6 Feet Beneath the Moon
# 211892  6 Feet Beneath the Moon

# %%
print("Número de linhas e colunas da tabela: ")
# Out:
# Número de linhas e colunas da tabela:

# %%
display(df_spotify.shape)
# Out:
# (211893, 5)

# %%
print("Quantidade de artistas diferentes da tabela:")
# Out:
# Quantidade de artistas diferentes da tabela:

# %%
display(df_spotify['artist_name'].nunique())
# Out:
# 5688

# %%
print("Informações da tabela: ")
# Out:
# Informações da tabela:

# %%
display(df_spotify.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211893 entries, 0 to 211892
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   timestamp    211893 non-null  object
#  1   duration_ms  211893 non-null  int64
#  2   track_name   211880 non-null  object
#  3   artist_name  211880 non-null  object
#  4   album_name   211880 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 8.1+ MB
# None

# %%
print("Descrição estatística da tabela: ")
# Out:
# Descrição estatística da tabela:

# %%
display(df_spotify.describe())
# Out:
#         duration_ms
# count  2.118930e+05
# mean   1.495219e+05
# std    9.206439e+04
# min    0.000000e+00
# 25%    9.119500e+04
# 50%    1.684060e+05
# 75%    2.084950e+05
# max    1.125699e+06

# %%
print("Entradas da coluna track_name: ")
nome_track = df_spotify['track_name']
display(nome_track)
# Out:
# Entradas da coluna track_name:
# 0                                   Silence
# 1               Mask Off - Marshmello Remix
# 2                                    Summer
# 3         Chasing Colors (feat. Noah Cyrus)
# 4                                   Know Me
#                         ...
# 211888                          Cementality
# 211889                          Cementality
# 211890                       A Lizard State
# 211891                          Will I Come
# 211892                            Ocean Bed
# Name: track_name, Length: 211893, dtype: object

# %%
print("Entradas da coluna artist_name e album_name: ")
artista_album = df_spotify[['artist_name', 'album_name']]
display(artista_album)
# Out:
# Entradas da coluna artist_name e album_name:
#        artist_name                         album_name
# 0       Marshmello                            Silence
# 1           Future                           Mask Off
# 2       Marshmello                            Joytime
# 3       Marshmello  Chasing Colors (feat. Noah Cyrus)
# 4       Marshmello                            Joytime
# ...            ...                                ...
# 211888  King Krule            6 Feet Beneath the Moon
# 211889  King Krule            6 Feet Beneath the Moon
# 211890  King Krule            6 Feet Beneath the Moon
# 211891  King Krule            6 Feet Beneath the Moon
# 211892  King Krule            6 Feet Beneath the Moon
#
# [211893 rows x 2 columns]

# %%
display(df_spotify.iloc[2000])
# Out:
# timestamp      2019-11-13 22:42:38+00:00
# duration_ms                         2397
# track_name                         Farsa
# artist_name                         UCLÃ
# album_name                         Farsa
# Name: 2000, dtype: object

# %%
display(df_spotify.loc[100: 104])
# Out:
#                      timestamp  duration_ms  \
# 100  2017-11-15 12:45:09+00:00       212627
# 101  2017-11-15 12:48:35+00:00       206197
# 102  2017-11-15 12:51:50+00:00       195200
# 103  2017-11-15 12:55:43+00:00       233239
# 104  2017-11-15 12:58:42+00:00       179155
#
#                             track_name  artist_name  \
# 100                              Faded  Alan Walker
# 101                            Know Me   Marshmello
# 102  Chasing Colors (feat. Noah Cyrus)   Marshmello
# 103                             Summer   Marshmello
# 104                          Moving On   Marshmello
#
#                             album_name
# 100                              Faded
# 101                            Joytime
# 102  Chasing Colors (feat. Noah Cyrus)
# 103                            Joytime
# 104                          Moving On

# %%
df_coldplay = df_spotify[df_spotify['artist_name'] == 'Coldplay']
display(df_coldplay)
# Out:
#                         timestamp  duration_ms  \
# 6067    2019-12-06 16:43:29+00:00          609
# 15452   2020-12-12 21:27:15+00:00       309600
# 15549   2020-12-14 02:59:19+00:00       258267
# 15581   2020-12-14 17:30:22+00:00       295533
# 15596   2020-12-14 20:34:26+00:00         1097
# ...                           ...          ...
# 209759  2025-09-17 01:15:34+00:00       256466
# 209760  2025-09-17 01:19:43+00:00       249400
# 209761  2025-09-17 01:26:59+00:00       436440
# 209762  2025-09-17 01:31:46+00:00       285345
# 211503  2025-09-29 09:48:35+00:00       226680
#
#                                                track_name artist_name  \
# 6067                                 Hymn for the Weekend    Coldplay
# 15452                                       The Scientist    Coldplay
# 15549                                Hymn for the Weekend    Coldplay
# 15581                                             Fix You    Coldplay
# ...

# %%
df_igor = df_spotify[(df_spotify['artist_name'] == 'Tyler, The Creator') & (df_spotify['album_name'] == 'IGOR')]
df_igor
# Out:
#                         timestamp  duration_ms                track_name  \
# 14872   2020-12-07 13:57:08+00:00       190067                 EARFQUAKE
# 16022   2020-12-18 23:46:13+00:00       190067                 EARFQUAKE
# 16086   2020-12-19 02:45:18+00:00       190067                 EARFQUAKE
# 16482   2020-12-21 18:14:35+00:00       190067                 EARFQUAKE
# 16724   2020-12-23 18:10:12+00:00       190067                 EARFQUAKE
# ...                           ...          ...                       ...
# 205359  2025-08-10 17:17:42+00:00          235  I DON'T LOVE YOU ANYMORE
# 205705  2025-08-15 02:13:01+00:00       212013                   I THINK
# 206820  2025-08-24 18:40:35+00:00       210253           A BOY IS A GUN*
# 211788  2025-10-01 16:11:41+00:00       212013                   I THINK
# 211809  2025-10-01 17:26:57+00:00       265480     ARE WE STILL FRIENDS?
#
#                artist_name album_name
# 14872   Tyler, The Creator       IGOR
# ...

# %%
df_spotify['duration_seconds'] = df_spotify['duration_ms'] / 1000
display(df_spotify['duration_ms'])
# Out:
# 0          48330
# 1          11190
# 2           5970
# 3          28640
# 4          31050
#            ...
# 211888    147493
# 211889     76650
# 211890    259746
# 211891    114987
# 211892    211453
# Name: duration_ms, Length: 211893, dtype: int64

# %%
df_spotify['artist_track'] = df_spotify['artist_name'] + '-' + df_spotify['track_name']
display(df_spotify['artist_track'])
# Out:
# 0                                   Marshmello-Silence
# 1                   Future-Mask Off - Marshmello Remix
# 2                                    Marshmello-Summer
# 3         Marshmello-Chasing Colors (feat. Noah Cyrus)
# 4                                   Marshmello-Know Me
#                               ...
# 211888                          King Krule-Cementality
# 211889                          King Krule-Cementality
# 211890                       King Krule-A Lizard State
# 211891                          King Krule-Will I Come
# 211892                            King Krule-Ocean Bed
# Name: artist_track, Length: 211893, dtype: object

# %%
mapa_nomes = {'track_name' : 'nome_musica', 'artist_name' : 'nome_artista'}
df_spotify_renomeado = df_spotify.rename(columns = mapa_nomes)
display(df_spotify_renomeado)
# Out:
#                         timestamp  duration_ms  \
# 0       2017-11-04 21:53:34+00:00        48330
# 1       2017-11-04 21:53:46+00:00        11190
# 2       2017-11-04 21:53:53+00:00         5970
# 3       2017-11-04 21:54:23+00:00        28640
# 4       2017-11-04 21:54:57+00:00        31050
# ...                           ...          ...
# 211888  2025-10-02 23:45:44+00:00       147493
# 211889  2025-10-02 23:47:02+00:00        76650
# 211890  2025-10-02 23:51:22+00:00       259746
# 211891  2025-10-02 23:53:17+00:00       114987
# 211892  2025-10-02 23:56:48+00:00       211453
#
#                               nome_musica nome_artista  \
# 0                                 Silence   Marshmello
# 1             Mask Off - Marshmello Remix       Future
# 2                                  Summer   Marshmello
# 3       Chasing Colors (feat. Noah Cyrus)   Marshmello
# 4                                 Know Me   Marshmello
# ...                                   ...          ...
# ...

# %%
df_spotify_sem_album = df_spotify.drop('album_name', axis=1)
display(df_spotify_sem_album)
# Out:
#                         timestamp  duration_ms  \
# 0       2017-11-04 21:53:34+00:00        48330
# 1       2017-11-04 21:53:46+00:00        11190
# 2       2017-11-04 21:53:53+00:00         5970
# 3       2017-11-04 21:54:23+00:00        28640
# 4       2017-11-04 21:54:57+00:00        31050
# ...                           ...          ...
# 211888  2025-10-02 23:45:44+00:00       147493
# 211889  2025-10-02 23:47:02+00:00        76650
# 211890  2025-10-02 23:51:22+00:00       259746
# 211891  2025-10-02 23:53:17+00:00       114987
# 211892  2025-10-02 23:56:48+00:00       211453
#
#                                track_name artist_name  duration_seconds  \
# 0                                 Silence  Marshmello            48.330
# 1             Mask Off - Marshmello Remix      Future            11.190
# 2                                  Summer  Marshmello             5.970
# 3       Chasing Colors (feat. Noah Cyrus)  Marshmello            28.640
# ...

# %%
df_spotify.drop('duration_ms', axis=1, inplace = True)
display(df_spotify)
# Out:
#                         timestamp                         track_name  \
# 0       2017-11-04 21:53:34+00:00                            Silence
# 1       2017-11-04 21:53:46+00:00        Mask Off - Marshmello Remix
# 2       2017-11-04 21:53:53+00:00                             Summer
# 3       2017-11-04 21:54:23+00:00  Chasing Colors (feat. Noah Cyrus)
# 4       2017-11-04 21:54:57+00:00                            Know Me
# ...                           ...                                ...
# 211888  2025-10-02 23:45:44+00:00                        Cementality
# 211889  2025-10-02 23:47:02+00:00                        Cementality
# 211890  2025-10-02 23:51:22+00:00                     A Lizard State
# 211891  2025-10-02 23:53:17+00:00                        Will I Come
# 211892  2025-10-02 23:56:48+00:00                          Ocean Bed
#
#        artist_name                         album_name  duration_seconds  \
# ...
